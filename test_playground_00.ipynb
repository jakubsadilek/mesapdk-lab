# %%
import gdsfactory as gf
gf.gpdk.PDK.activate()

# %%
gf.components.coupler().plot()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 1 Axes>

# %%
gf.components.straight_heater_metal_simple()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 1 Axes>

# %%
from ekin_master_die import ekn_master_die_ds, edge_coupler_array_ekn_def, edge_coupler_array_ekn_def_centerskip, edge_coupler_array_ekn_def_butt
from test_crosssections import xs_ekn300_te_IMGREV
ekn_bend = gf.partial(gf.components.bend_euler, radius = 300, cross_section = xs_ekn300_te_IMGREV, width=0.5)
c = gf.components.mmi(inputs = 1, outputs = 2,cross_section=xs_ekn300_te_IMGREV)
c.plot()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 1 Axes>

# %%
from EKST_v2_UWWG import ekst_v2_uwwg_master
from ekin_master_die import edge_coupler_array_ekn_def_butt
from logo_maker import svg_logo

logo = svg_logo(
            svg_path="./static/AQO_logo2.svg",
            layer=(5,0),
            target_width_um=1500.0,   # final width in um
            resolution=0.08,         # smaller -> smoother curves
            center=True,
        )
ekst_v2_uwwg_master(ext_grp_spacing=127, 
                        ec_array_def=edge_coupler_array_ekn_def_butt, 
                        logo=logo, 
                        logo_loc=(0,-3000)).plot()
# Out:
# c:\Users\BosdurmazEB\AppData\Local\Programs\Python\Python311\Lib\site-packages\gdsfactory\components\bends\bend_euler.py:110: UserWarning: {'width': 50.0} ignored for cross_section 'xs_db918c36'
#   x = gf.get_cross_section(cross_section, width=width or x.width)
# c:\Users\BosdurmazEB\AppData\Local\Programs\Python\Python311\Lib\site-packages\gdsfactory\components\bends\bend_euler.py:110: UserWarning: {'width': 60.0} ignored for cross_section 'xs_556dc3e5'
#   x = gf.get_cross_section(cross_section, width=width or x.width)
# c:\Users\BosdurmazEB\AppData\Local\Programs\Python\Python311\Lib\site-packages\gdsfactory\components\bends\bend_euler.py:110: UserWarning: {'width': 70.0} ignored for cross_section 'xs_250ba38b'
#   x = gf.get_cross_section(cross_section, width=width or x.width)
# c:\Users\BosdurmazEB\AppData\Local\Programs\Python\Python311\Lib\site-packages\gdsfactory\components\bends\bend_euler.py:110: UserWarning: {'width': 80.0} ignored for cross_section 'xs_2998b858'
#   x = gf.get_cross_section(cross_section, width=width or x.width)
# c:\Users\BosdurmazEB\AppData\Local\Programs\Python\Python311\Lib\site-packages\gdsfactory\components\bends\bend_euler.py:110: UserWarning: {'width': 2.5} ignored for cross_section 'xs_24911e99'
#   x = gf.get_cross_section(cross_section, width=width or x.width)
